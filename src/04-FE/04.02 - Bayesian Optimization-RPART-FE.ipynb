# %%
#Optimizacion Bayesiana de hiperparametros de  rpart
#funciona automaticamente con EXPERIMENTOS
#va generando incrementalmente salidas para kaggle

#limpio la memoria
rm( list=ls() )  #remove all objects
gc()             #garbage collection

library("data.table")
library("rlist")
library("yaml")

library("rpart")
library("parallel")

#paquetes necesarios para la Bayesian Optimization
library("DiceKriging")
library("mlrMBO")
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  614775 32.9 1331818    71.2 1202683  64.3
# Vcells 1151597  8.8 8388608    64.0 1801065  13.8
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Warning message: 'mlr' is in 'maintenance-only' mode since July 2019.
# Future development will only happen in 'mlr3'
# (<https://mlr3.mlr-org.com>). Due to the focus on 'mlr3' there might be
# uncaught bugs meanwhile in {mlr} - please consider switching.
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# Warning message:
# “no DISPLAY variable so Tk is not available”

# %%
#para poder usarlo en la PC y en la nube
switch ( Sys.info()[['sysname']],
         Windows = { directory.root   <-  "M:\\" },   #Microsoft Windows
         Darwin  = { directory.root   <-  "~/dm/" },  #Apple MAC
#         Linux   = { directory.root   <-  "~/buckets/b1/" }  #Entorno Google Cloud
         Linux   = { directory.root   <-  "~/" }  #Hay un problema en el almacenamiento en cloud del BO por el momento se graba en el usuario
       )
#defino la carpeta donde trabajo

#Hay un error en el almacenamiento 

setwd( directory.root )

# %%
kexperimento  <- NA   #NA si se corre la primera vez, un valor concreto si es para continuar procesando

kscript           <- "04.02 - BO Rpart FE"
kBO_iter    <-  200   #cantidad de iteraciones de la Optimizacion Bayesiana

kcarpeta_datasets    <- "./buckets/b1/datasets/"                          #VM o Ubuntu

#Archivo con datos etiquetados para entrenamiento
karchivo_entrada      <-  paste0(kcarpeta_datasets, "competencia1_2022_FE.csv")


#Ganancia por TP
kTPGain               <-  78000

#Pérdida por FP
kFPGain               <-  -2000


hs  <- makeParamSet(
          makeNumericParam("cp"       , lower= -1   , upper=    0.1),
          makeIntegerParam("minsplit" , lower=  1L  , upper= 8000L),  #la letra L al final significa ENTERO
          makeIntegerParam("minbucket", lower=  1L  , upper= 2000L),
          makeIntegerParam("maxdepth" , lower=  3L  , upper=   20L),
          forbidden = quote( minbucket > 0.5*minsplit ) )


ksemilla_azar  <- 102191

# %% [markdown]
# #------------------------------------------------------------------------------
# #Funcion que lleva el registro de los experimentos
#
# get_experimento  <- function()
# {
#   if( !file.exists( "./maestro.yaml" ) )  cat( file="./maestro.yaml", "experimento: 1000" )
#
#   exp  <- read_yaml( "./maestro.yaml" )
#   experimento_actual  <- exp$experimento
#
#   exp$experimento  <- as.integer(exp$experimento + 1)
#   Sys.chmod( "./maestro.yaml", mode = "0644", use_umask = TRUE)
#   write_yaml( exp, "./maestro.yaml" )
#   Sys.chmod( "./maestro.yaml", mode = "0444", use_umask = TRUE) #dejo el archivo readonly
#
#   return( experimento_actual )
# }

# %%
#------------------------------------------------------------------------------
#Funcion que lleva el registro de los experimentos

get_experimento  <- function()
{
  if( !file.exists( "./maestro.yaml" ) )  cat( file="./maestro.yaml", "experimento: 1000" )

  exp  <- read_yaml( "./maestro.yaml" )
  experimento_actual  <- exp$experimento

  exp$experimento  <- as.integer(exp$experimento + 1)
  Sys.chmod( "./maestro.yaml", mode = "0644", use_umask = TRUE)
  write_yaml( exp, "./maestro.yaml" )
  Sys.chmod( "./maestro.yaml", mode = "0444", use_umask = TRUE) #dejo el archivo readonly

  return( experimento_actual )
}

# %%
#------------------------------------------------------------------------------
#funcion para particionar, es la que Andres reemplaza con caret

particionar  <- function( data, division, agrupa="", campo="fold", start=1, seed=NA )
{
  if( !is.na( seed)  )   set.seed( seed )

  bloque  <- unlist( mapply(  function(x,y) { rep( y, x ) }, division, seq( from=start, length.out=length(division) )  ) )

  data[ , (campo) :=  sample( rep( bloque, ceiling(.N/length(bloque))) )[1:.N],
           by= agrupa ]
}
#------------------------------------------------------------------------------

# %%
ArbolSimple  <- function( fold_test, data, param )
{
  #genero el modelo
  modelo  <- rpart("clase_ternaria ~ .", 
                   data= data[ fold != fold_test, ],
                   xval= 0,
                   control= param )

  #aplico el modelo a los datos de testing, fold==2
  prediccion  <- predict( modelo, data[ fold==fold_test, ], type = "prob")

  prob_baja2  <- prediccion[, "BAJA+2"]

  ganancia_testing  <- sum(  data[ fold==fold_test ][ prob_baja2 >0.025,  ifelse( clase_ternaria=="BAJA+2", kTPGain, kFPGain ) ] )

  return( ganancia_testing )
}

# %%
#------------------------------------------------------------------------------

ArbolesCrossValidation  <- function( data, param, qfolds, pagrupa, semilla )
{
  divi  <- rep( 1, qfolds )
  particionar( data, divi, seed=semilla, agrupa=pagrupa )

  ganancias  <- mcmapply( ArbolSimple, 
                          seq(qfolds), # 1 2 3 4 5  
                          MoreArgs= list( data, param), 
                          SIMPLIFY= FALSE,
                          mc.cores= 5 )   #se puede subir a 5 si posee Linux o Mac OS

  data[ , fold := NULL ]
  #devuelvo la primer ganancia y el promedio
  return( mean( unlist( ganancias )) *  qfolds )   #aqui normalizo la ganancia
}

# %%
#------------------------------------------------------------------------------
#esta funcion solo puede recibir los parametros que se estan optimizando
#el resto de los parametros se pasan como variables globales

EstimarGanancia  <- function( x )
{
   GLOBAL_iteracion  <<-  GLOBAL_iteracion + 1

   xval_folds  <- 5
   ganancia  <-  ArbolesCrossValidation( dtrain, param=x, qfolds= xval_folds, pagrupa="clase_ternaria", semilla=ksemilla_azar )

   #si tengo una ganancia superadora, genero el archivo para Kaggle
   if(  ganancia > GLOBAL_ganancia_max )
   {
     GLOBAL_ganancia_max <<-  ganancia  #asigno la nueva maxima ganancia
    
     modelo  <- rpart("clase_ternaria ~ .",
                      data= dtrain,
                      xval= 0,
                      control= x )

     #genero el vector con la prediccion, la probabilidad de ser positivo
     prediccion  <- predict( modelo, dapply)

     prob_baja2  <- prediccion[, "BAJA+2"]
     Predicted   <- ifelse( prob_baja2 > 0.025, 1, 0 )

     entrega  <-  as.data.table( list( "numero_de_cliente"=dapply$numero_de_cliente, "Predicted"=Predicted)  )

     #genero el archivo para Kaggle
     fwrite( entrega, 
             file= paste0(kkaggle, GLOBAL_iteracion, ".csv" ),
             sep=  "," )
   }

   return( ganancia )
}
#------------------------------------------------------------------------------

# %%
#Aqui empieza el programa

if( is.na(kexperimento ) )   kexperimento <- get_experimento()  #creo el experimento
# Out:
# Warning message in readLines(file, warn = readLines.warn):
# “incomplete final line found on './maestro.yaml'”

# %%
#en estos archivos quedan los resultados
kbayesiana  <- paste0("./E",  kexperimento, "_rpart.RDATA" )
kkaggle     <- paste0("./E",kexperimento, "_rpart_kaggle_" )

# %%
GLOBAL_ganancia_max  <-  -Inf
GLOBAL_iteracion  <- 0

# %%
#cargo los datos
dataset <- fread(karchivo_entrada)

#Para hacer pruebas rapidas puedo reducir el dataset a una fraccion
#subsample <- sample(1:nrow(dataset), .1 * nrow(dataset))
#dataset <- dataset[subsample,]

dtrain  <- dataset[ foto_mes==202101 ]  #defino donde voy a entrenar

dapply  <- dataset[ foto_mes==202103 ]  #defino donde voy a aplicar el modelo

# %%
#Aqui comienza la configuracion de la Bayesian Optimization

configureMlr( show.learner.output = FALSE)

funcion_optimizar  <- EstimarGanancia

#configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
#por favor, no desesperarse por lo complejo
obj.fun  <- makeSingleObjectiveFunction(
              fn=       funcion_optimizar,
              minimize= FALSE,   #estoy Maximizando la ganancia
              noisy=    TRUE,
              par.set=  hs,
              has.simple.signature = FALSE
             )

ctrl  <- makeMBOControl( save.on.disk.at.time= 60,  save.file.path= kbayesiana)
ctrl  <- setMBOControlTermination(ctrl, iters= kBO_iter )
ctrl  <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

surr.km  <-  makeLearner("regr.km", predict.type= "se", covtype= "matern3_2", control= list(trace= TRUE))

# %%
#inicio la optimizacion bayesiana
if(!file.exists(kbayesiana)) {
  run  <- mbo(obj.fun, learner = surr.km, control = ctrl)
} else  run  <- mboContinue( kbayesiana )   #retomo en caso que ya exista
# Out:
# Computing y column(s) for design. Not provided.
#
# [mbo] 0: cp=-0.623; minsplit=2148; minbucket=82; maxdepth=8 : y = 1.9e+07 : 26.2 secs : initdesign
#
# [mbo] 0: cp=-0.884; minsplit=5317; minbucket=957; maxdepth=9 : y = 1.59e+07 : 13.0 secs : initdesign
#
# [mbo] 0: cp=-0.529; minsplit=6356; minbucket=1743; maxdepth=19 : y = 1.53e+07 : 13.9 secs : initdesign
#
# [mbo] 0: cp=0.0678; minsplit=4959; minbucket=721; maxdepth=17 : y = 0 : 7.5 secs : initdesign
#
# [mbo] 0: cp=-0.427; minsplit=7362; minbucket=424; maxdepth=12 : y = 1.5e+07 : 14.8 secs : initdesign
#
# [mbo] 0: cp=-0.338; minsplit=3471; minbucket=622; maxdepth=16 : y = 1.75e+07 : 16.5 secs : initdesign
#
# [mbo] 0: cp=-0.479; minsplit=3888; minbucket=1047; maxdepth=4 : y = 1.69e+07 : 8.2 secs : initdesign
#
# [mbo] 0: cp=-0.155; minsplit=1503; minbucket=295; maxdepth=7 : y = 1.94e+07 : 23.0 secs : initdesign
#
# [mbo] 0: cp=-0.0385; minsplit=6690; minbucket=756; maxdepth=20 : y = 1.52e+07 : 15.3 secs : initdesign
#
# [mbo] 0: cp=-0.26; minsplit=5804; minbucket=1202; maxdepth=11 : y = 1.59e+07 : 13.6 secs : initdesign
#
# [mbo] 0: cp=-0.943; minsplit=7651; minbucket=1326; maxdepth=15 : y = 1.53e+07 : 13.4 secs : initdesign
#
# [mbo] 0: cp=-0.762; minsplit=4198; minbucket=199; maxdepth=9 : y = 1.6e+07 : 13.0 secs : initdesign
#
# [mbo] 0: cp=-0.835; minsplit=486; minbucket=165; maxdepth=3 : y = 1.6e+07 : 6.4 secs : initdesign
#
# [mbo] 0: cp=-0.191; minsplit=5168; minbucket=791; maxdepth=18 : y = 1.58e+07 : 15.8 secs : initdesign
#
# [mbo] 0: cp=-0.52; minsplit=6204; minbucket=1206; maxdepth=14 : y = 1.53e+07 : 13.9 secs : initdesign
#
# [mbo] 0: cp=-0.78; minsplit=4994; minbucket=381; maxdepth=20 : y = 1.56e+07 : 16.9 secs : initdesign
#
# Saved the current state after iteration 1 in the file ./E1000_rpart.RDATA.
#
# [mbo] 1: cp=-0.114; minsplit=32; minbucket=1; maxdepth=3 : y = 1.74e+07 : 6.2 secs : infill_ei
#
# [mbo] 2: cp=-0.647; minsplit=2594; minbucket=1294; maxdepth=3 : y = 1.59e+07 : 6.4 secs : infill_ei
#
# [mbo] 3: cp=-0.579; minsplit=568; minbucket=2; maxdepth=3 : y = 1.74e+07 : 6.2 secs : infill_ei
#
# [mbo] 4: cp=-0.152; minsplit=7555; minbucket=68; maxdepth=3 : y = 1.6e+07 : 5.9 secs : infill_ei
#
# [mbo] 5: cp=-0.148; minsplit=155; minbucket=72; maxdepth=20 : y = 1.56e+07 : 25.0 secs : infill_ei
#
# [mbo] 6: cp=-0.156; minsplit=1790; minbucket=895; maxdepth=3 : y = 1.57e+07 : 6.5 secs : infill_ei
#
# Saved the current state after iteration 7 in the file ./E1000_rpart.RDATA.
#
# [mbo] 7: cp=-0.846; minsplit=2596; minbucket=93; maxdepth=3 : y = 1.69e+07 : 6.2 secs : infill_ei
#
# [mbo] 8: cp=-0.176; minsplit=194; minbucket=1; maxdepth=9 : y = 2.02e+07 : 27.4 secs : infill_ei
#
# [mbo] 9: cp=-0.219; minsplit=8; minbucket=4; maxdepth=7 : y = 1.93e+07 : 11.4 secs : infill_ei
#
# [mbo] 10: cp=-0.625; minsplit=137; minbucket=4; maxdepth=20 : y = 1.52e+07 : 27.5 secs : infill_ei
#
# Saved the current state after iteration 11 in the file ./E1000_rpart.RDATA.
#
# [mbo] 11: cp=-0.313; minsplit=62; minbucket=1; maxdepth=7 : y = 1.96e+07 : 11.9 secs : infill_ei
#
# [mbo] 12: cp=-0.36; minsplit=321; minbucket=158; maxdepth=3 : y = 1.6e+07 : 6.4 secs : infill_ei
#
# [mbo] 13: cp=-0.146; minsplit=5519; minbucket=1; maxdepth=9 : y = 1.58e+07 : 12.9 secs : infill_ei
#
# [mbo] 14: cp=-0.287; minsplit=22; minbucket=5; maxdepth=13 : y = 1.38e+07 : 19.3 secs : infill_ei
#
# [mbo] 15: cp=-0.997; minsplit=4689; minbucket=44; maxdepth=7 : y = 1.61e+07 : 10.8 secs : infill_ei
#
# Saved the current state after iteration 16 in the file ./E1000_rpart.RDATA.
#
# [mbo] 16: cp=-0.71; minsplit=942; minbucket=471; maxdepth=7 : y = 1.89e+07 : 11.5 secs : infill_ei
#
# [mbo] 17: cp=-0.383; minsplit=6010; minbucket=802; maxdepth=8 : y = 1.58e+07 : 11.5 secs : infill_ei
#
# [mbo] 18: cp=0.0992; minsplit=516; minbucket=258; maxdepth=9 : y = 0 : 6.3 secs : infill_ei
#
# [mbo] 19: cp=-0.316; minsplit=3541; minbucket=619; maxdepth=6 : y = 1.76e+07 : 10.0 secs : infill_ei
#
# [mbo] 20: cp=-0.678; minsplit=5461; minbucket=1; maxdepth=6 : y = 1.58e+07 : 9.5 secs : infill_ei
#
# [mbo] 21: cp=-0.34; minsplit=7483; minbucket=1998; maxdepth=20 : y = 1.53e+07 : 12.4 secs : infill_ei
#
# Saved the current state after iteration 22 in the file ./E1000_rpart.RDATA.
#
# [mbo] 22: cp=-0.588; minsplit=1409; minbucket=704; maxdepth=9 : y = 1.9e+07 : 13.4 secs : infill_ei
#
# [mbo] 23: cp=-0.178; minsplit=103; minbucket=48; maxdepth=7 : y = 2.05e+07 : 22.4 secs : infill_ei
#
# [mbo] 24: cp=-0.506; minsplit=13; minbucket=1; maxdepth=8 : y = 1.89e+07 : 12.7 secs : infill_ei
#
# [mbo] 25: cp=-0.685; minsplit=1158; minbucket=573; maxdepth=12 : y = 1.89e+07 : 16.4 secs : infill_ei
#
# Saved the current state after iteration 26 in the file ./E1000_rpart.RDATA.
#
# [mbo] 26: cp=-0.714; minsplit=3979; minbucket=1985; maxdepth=16 : y = 1.75e+07 : 13.3 secs : infill_ei
#
# [mbo] 27: cp=-0.952; minsplit=7976; minbucket=2000; maxdepth=3 : y = 1.53e+07 : 6.3 secs : infill_ei
#
# [mbo] 28: cp=-0.165; minsplit=10; minbucket=2; maxdepth=7 : y = 1.9e+07 : 11.4 secs : infill_ei
#
# [mbo] 29: cp=-0.187; minsplit=1139; minbucket=370; maxdepth=8 : y = 1.9e+07 : 12.7 secs : infill_ei
#
# [mbo] 30: cp=-0.607; minsplit=7355; minbucket=568; maxdepth=3 : y = 1.53e+07 : 6.4 secs : infill_ei
#
# [mbo] 31: cp=-0.711; minsplit=97; minbucket=46; maxdepth=19 : y = 1.35e+07 : 25.0 secs : infill_ei
#
# Saved the current state after iteration 32 in the file ./E1000_rpart.RDATA.
#
# [mbo] 32: cp=-0.695; minsplit=3478; minbucket=1732; maxdepth=9 : y = 1.75e+07 : 12.8 secs : infill_ei
#
# [mbo] 33: cp=-0.55; minsplit=24; minbucket=10; maxdepth=10 : y = 1.72e+07 : 15.7 secs : infill_ei
#
# [mbo] 34: cp=-0.485; minsplit=304; minbucket=28; maxdepth=20 : y = 1.52e+07 : 26.4 secs : infill_ei
#
# Saved the current state after iteration 35 in the file ./E1000_rpart.RDATA.
#
# [mbo] 35: cp=-0.331; minsplit=151; minbucket=4; maxdepth=8 : y = 2.04e+07 : 12.7 secs : infill_ei
#
# [mbo] 36: cp=-0.842; minsplit=7730; minbucket=2000; maxdepth=20 : y = 1.53e+07 : 13.1 secs : infill_ei
#
# [mbo] 37: cp=-0.244; minsplit=222; minbucket=6; maxdepth=3 : y = 1.74e+07 : 6.3 secs : infill_ei
#
# [mbo] 38: cp=-0.328; minsplit=5495; minbucket=3; maxdepth=9 : y = 1.57e+07 : 12.9 secs : infill_ei
#
# [mbo] 39: cp=-0.739; minsplit=3875; minbucket=1936; maxdepth=3 : y = 1.65e+07 : 6.5 secs : infill_ei
#
# Saved the current state after iteration 40 in the file ./E1000_rpart.RDATA.
#
# [mbo] 40: cp=-0.0726; minsplit=663; minbucket=326; maxdepth=7 : y = 1.97e+07 : 11.7 secs : infill_ei
#
# [mbo] 41: cp=-0.0505; minsplit=48; minbucket=9; maxdepth=3 : y = 1.74e+07 : 6.4 secs : infill_ei
#
# [mbo] 42: cp=-0.0667; minsplit=3947; minbucket=1970; maxdepth=6 : y = 1.75e+07 : 9.9 secs : infill_ei
#
# [mbo] 43: cp=-0.0739; minsplit=7819; minbucket=327; maxdepth=3 : y = 1.53e+07 : 6.4 secs : infill_ei
#
# [mbo] 44: cp=-0.18; minsplit=2110; minbucket=7; maxdepth=6 : y = 1.88e+07 : 10.2 secs : infill_ei
#
# [mbo] 45: cp=-0.0909; minsplit=1076; minbucket=537; maxdepth=12 : y = 1.91e+07 : 16.4 secs : infill_ei
#
# Saved the current state after iteration 46 in the file ./E1000_rpart.RDATA.
#
# [mbo] 46: cp=-0.615; minsplit=3768; minbucket=1879; maxdepth=13 : y = 1.73e+07 : 13.6 secs : infill_ei
#
# [mbo] 47: cp=-0.0638; minsplit=210; minbucket=102; maxdepth=14 : y = 1.65e+07 : 19.7 secs : infill_ei
#
# [mbo] 48: cp=-0.0957; minsplit=1170; minbucket=580; maxdepth=7 : y = 1.9e+07 : 11.6 secs : infill_ei
#
# [mbo] 49: cp=-0.644; minsplit=926; minbucket=460; maxdepth=11 : y = 1.85e+07 : 15.8 secs : infill_ei
#
# Saved the current state after iteration 50 in the file ./E1000_rpart.RDATA.
#
# [mbo] 50: cp=-0.0832; minsplit=4426; minbucket=1997; maxdepth=20 : y = 1.62e+07 : 13.2 secs : infill_ei
#
# [mbo] 51: cp=-0.326; minsplit=32; minbucket=7; maxdepth=5 : y = 1.97e+07 : 9.1 secs : infill_ei
#
# [mbo] 52: cp=-0.381; minsplit=27; minbucket=9; maxdepth=20 : y = 1.01e+07 : 28.0 secs : infill_ei
#
# [mbo] 53: cp=-0.336; minsplit=1809; minbucket=903; maxdepth=9 : y = 1.83e+07 : 13.3 secs : infill_ei
#
# Saved the current state after iteration 54 in the file ./E1000_rpart.RDATA.
#
# [mbo] 54: cp=-0.6; minsplit=317; minbucket=3; maxdepth=12 : y = 1.97e+07 : 17.7 secs : infill_ei
#
# [mbo] 55: cp=-0.461; minsplit=54; minbucket=9; maxdepth=6 : y = 2.01e+07 : 10.4 secs : infill_ei
#
# [mbo] 56: cp=-0.475; minsplit=91; minbucket=4; maxdepth=8 : y = 2.02e+07 : 12.8 secs : infill_ei
#
# [mbo] 57: cp=-0.469; minsplit=6138; minbucket=2; maxdepth=7 : y = 1.54e+07 : 11.2 secs : infill_ei
#
# [mbo] 58: cp=-0.453; minsplit=1276; minbucket=638; maxdepth=8 : y = 1.87e+07 : 12.6 secs : infill_ei
#
# Saved the current state after iteration 59 in the file ./E1000_rpart.RDATA.
#
# [mbo] 59: cp=-0.926; minsplit=231; minbucket=1; maxdepth=3 : y = 1.74e+07 : 6.3 secs : infill_ei
#
# [mbo] 60: cp=-0.902; minsplit=45; minbucket=1; maxdepth=20 : y = 1.32e+07 : 28.2 secs : infill_ei
#
# [mbo] 61: cp=-0.787; minsplit=4082; minbucket=1997; maxdepth=13 : y = 1.75e+07 : 13.3 secs : infill_ei
#
# [mbo] 62: cp=-0.479; minsplit=24; minbucket=10; maxdepth=4 : y = 1.74e+07 : 7.8 secs : infill_ei
#
# Saved the current state after iteration 63 in the file ./E1000_rpart.RDATA.
#
# [mbo] 63: cp=-0.428; minsplit=15; minbucket=4; maxdepth=7 : y = 1.93e+07 : 11.5 secs : infill_ei
#
# [mbo] 64: cp=-0.179; minsplit=484; minbucket=233; maxdepth=12 : y = 1.94e+07 : 17.4 secs : infill_ei
#
# [mbo] 65: cp=-0.13; minsplit=655; minbucket=318; maxdepth=9 : y = 1.88e+07 : 14.1 secs : infill_ei
#
# [mbo] 66: cp=-0.819; minsplit=7998; minbucket=1996; maxdepth=3 : y = 1.53e+07 : 6.4 secs : infill_ei
#
# [mbo] 67: cp=-0.594; minsplit=3813; minbucket=2; maxdepth=12 : y = 1.63e+07 : 16.5 secs : infill_ei
#
# Saved the current state after iteration 68 in the file ./E1000_rpart.RDATA.
#
# [mbo] 68: cp=-0.609; minsplit=29; minbucket=14; maxdepth=8 : y = 1.96e+07 : 13.1 secs : infill_ei
#
# [mbo] 69: cp=-0.463; minsplit=24; minbucket=11; maxdepth=10 : y = 1.7e+07 : 15.8 secs : infill_ei
#
# [mbo] 70: cp=-0.241; minsplit=2551; minbucket=1268; maxdepth=20 : y = 1.86e+07 : 15.3 secs : infill_ei
#
# [mbo] 71: cp=-0.999; minsplit=1608; minbucket=2; maxdepth=13 : y = 1.88e+07 : 18.3 secs : infill_ei
#
# Saved the current state after iteration 72 in the file ./E1000_rpart.RDATA.
#
# [mbo] 72: cp=-0.194; minsplit=474; minbucket=9; maxdepth=6 : y = 2.02e+07 : 10.5 secs : infill_ei
#
# [mbo] 73: cp=-0.776; minsplit=6906; minbucket=77; maxdepth=7 : y = 1.55e+07 : 10.7 secs : infill_ei
#
# [mbo] 74: cp=-0.738; minsplit=6812; minbucket=1668; maxdepth=17 : y = 1.53e+07 : 14.0 secs : infill_ei
#
# [mbo] 75: cp=-0.599; minsplit=4123; minbucket=840; maxdepth=6 : y = 1.66e+07 : 10.0 secs : infill_ei
#
# [mbo] 76: cp=-0.0773; minsplit=2256; minbucket=58; maxdepth=9 : y = 1.79e+07 : 13.6 secs : infill_ei
#
# Saved the current state after iteration 77 in the file ./E1000_rpart.RDATA.
#
# [mbo] 77: cp=-0.982; minsplit=25; minbucket=11; maxdepth=9 : y = 1.85e+07 : 14.5 secs : infill_ei
#
# [mbo] 78: cp=-0.962; minsplit=1930; minbucket=949; maxdepth=11 : y = 1.87e+07 : 14.8 secs : infill_ei
#
# [mbo] 79: cp=-0.473; minsplit=695; minbucket=8; maxdepth=7 : y = 2.11e+07 : 22.4 secs : infill_ei
#
# [mbo] 80: cp=-0.476; minsplit=1663; minbucket=11; maxdepth=7 : y = 1.96e+07 : 11.6 secs : infill_ei
#
# Saved the current state after iteration 81 in the file ./E1000_rpart.RDATA.
#
# [mbo] 81: cp=-0.271; minsplit=4149; minbucket=1997; maxdepth=20 : y = 1.75e+07 : 13.4 secs : infill_ei
#
# [mbo] 82: cp=-0.143; minsplit=2667; minbucket=1333; maxdepth=14 : y = 1.84e+07 : 14.8 secs : infill_ei
#
# [mbo] 83: cp=-1; minsplit=3163; minbucket=1570; maxdepth=16 : y = 1.78e+07 : 14.8 secs : infill_ei
#
# [mbo] 84: cp=-0.999; minsplit=1552; minbucket=776; maxdepth=3 : y = 1.57e+07 : 6.5 secs : infill_ei
#
# [mbo] 85: cp=-0.474; minsplit=571; minbucket=274; maxdepth=7 : y = 2.11e+07 : 22.6 secs : infill_ei
#
# Saved the current state after iteration 86 in the file ./E1000_rpart.RDATA.
#
# [mbo] 86: cp=-0.471; minsplit=3793; minbucket=1891; maxdepth=7 : y = 1.73e+07 : 11.0 secs : infill_ei
#
# [mbo] 87: cp=-0.965; minsplit=3142; minbucket=1; maxdepth=15 : y = 1.73e+07 : 20.1 secs : infill_ei
#
# [mbo] 88: cp=-0.239; minsplit=4017; minbucket=1989; maxdepth=16 : y = 1.75e+07 : 13.5 secs : infill_ei
#
# [mbo] 89: cp=-0.73; minsplit=2104; minbucket=1050; maxdepth=12 : y = 1.9e+07 : 15.4 secs : infill_ei
#
# Saved the current state after iteration 90 in the file ./E1000_rpart.RDATA.
#
# [mbo] 90: cp=-0.832; minsplit=1743; minbucket=855; maxdepth=12 : y = 1.85e+07 : 15.6 secs : infill_ei
#
# [mbo] 91: cp=-0.916; minsplit=1451; minbucket=1; maxdepth=10 : y = 2.02e+07 : 14.9 secs : infill_ei
#
# [mbo] 92: cp=-0.899; minsplit=1171; minbucket=585; maxdepth=8 : y = 1.9e+07 : 12.7 secs : infill_ei
#
# [mbo] 93: cp=-0.936; minsplit=2068; minbucket=4; maxdepth=8 : y = 1.89e+07 : 12.4 secs : infill_ei
#
# Saved the current state after iteration 94 in the file ./E1000_rpart.RDATA.
#
# [mbo] 94: cp=-0.929; minsplit=9; minbucket=2; maxdepth=11 : y = 1.72e+07 : 16.7 secs : infill_ei
#
# [mbo] 95: cp=-0.881; minsplit=2025; minbucket=3; maxdepth=10 : y = 1.87e+07 : 14.6 secs : infill_ei
#
# [mbo] 96: cp=-0.911; minsplit=2452; minbucket=1223; maxdepth=12 : y = 1.87e+07 : 14.9 secs : infill_ei
#
# [mbo] 97: cp=-0.103; minsplit=8000; minbucket=1994; maxdepth=13 : y = 1.53e+07 : 12.4 secs : infill_ei
#
# Saved the current state after iteration 98 in the file ./E1000_rpart.RDATA.
#
# [mbo] 98: cp=-0.601; minsplit=1094; minbucket=545; maxdepth=15 : y = 1.93e+07 : 17.6 secs : infill_ei
#
# [mbo] 99: cp=-0.242; minsplit=7995; minbucket=1428; maxdepth=20 : y = 1.53e+07 : 13.8 secs : infill_ei
#
# [mbo] 100: cp=-0.78; minsplit=858; minbucket=404; maxdepth=12 : y = 1.81e+07 : 16.7 secs : infill_ei
#
# [mbo] 101: cp=-0.47; minsplit=543; minbucket=133; maxdepth=7 : y = 2.17e+07 : 22.5 secs : infill_ei
#
# Saved the current state after iteration 102 in the file ./E1000_rpart.RDATA.
#
# [mbo] 102: cp=-0.91; minsplit=2950; minbucket=1; maxdepth=6 : y = 1.85e+07 : 9.9 secs : infill_ei
#
# [mbo] 103: cp=-1; minsplit=849; minbucket=136; maxdepth=20 : y = 1.94e+07 : 22.9 secs : infill_ei
#
# [mbo] 104: cp=-1; minsplit=7028; minbucket=115; maxdepth=20 : y = 1.52e+07 : 19.5 secs : infill_ei
#
# [mbo] 105: cp=-0.816; minsplit=3962; minbucket=2; maxdepth=14 : y = 1.62e+07 : 18.7 secs : infill_ei
#
# Saved the current state after iteration 106 in the file ./E1000_rpart.RDATA.
#
# [mbo] 106: cp=-0.531; minsplit=7955; minbucket=2000; maxdepth=3 : y = 1.53e+07 : 6.9 secs : infill_ei
#
# [mbo] 107: cp=-0.273; minsplit=7996; minbucket=2000; maxdepth=3 : y = 1.53e+07 : 6.3 secs : infill_ei
#
# [mbo] 108: cp=-0.979; minsplit=2079; minbucket=1033; maxdepth=20 : y = 1.9e+07 : 15.9 secs : infill_ei
#
# [mbo] 109: cp=-0.664; minsplit=7998; minbucket=1995; maxdepth=15 : y = 1.53e+07 : 12.4 secs : infill_ei
#
# [mbo] 110: cp=-0.42; minsplit=7963; minbucket=1965; maxdepth=3 : y = 1.53e+07 : 6.4 secs : infill_ei
#
# [mbo] 111: cp=-0.802; minsplit=2265; minbucket=1121; maxdepth=8 : y = 1.87e+07 : 12.3 secs : infill_ei
#
# Saved the current state after iteration 112 in the file ./E1000_rpart.RDATA.
#
# [mbo] 112: cp=-0.216; minsplit=3; minbucket=1; maxdepth=18 : y = 1.02e+07 : 26.1 secs : infill_ei
#
# [mbo] 113: cp=-0.988; minsplit=577; minbucket=287; maxdepth=17 : y = 1.86e+07 : 20.3 secs : infill_ei
#
# [mbo] 114: cp=-0.156; minsplit=5491; minbucket=1999; maxdepth=20 : y = 1.59e+07 : 13.0 secs : infill_ei
#
# Saved the current state after iteration 115 in the file ./E1000_rpart.RDATA.
#
# [mbo] 115: cp=-0.69; minsplit=56; minbucket=18; maxdepth=3 : y = 1.68e+07 : 6.4 secs : infill_ei
#
# [mbo] 116: cp=-0.468; minsplit=314; minbucket=60; maxdepth=7 : y = 2.08e+07 : 11.7 secs : infill_ei
#
# [mbo] 117: cp=-0.439; minsplit=852; minbucket=244; maxdepth=3 : y = 1.59e+07 : 6.6 secs : infill_ei
#
# [mbo] 118: cp=-0.226; minsplit=2600; minbucket=1295; maxdepth=5 : y = 1.84e+07 : 9.0 secs : infill_ei
#
# [mbo] 119: cp=-0.152; minsplit=1289; minbucket=95; maxdepth=12 : y = 1.98e+07 : 17.4 secs : infill_ei
#
# Saved the current state after iteration 120 in the file ./E1000_rpart.RDATA.
#
# [mbo] 120: cp=-0.218; minsplit=4976; minbucket=35; maxdepth=3 : y = 1.62e+07 : 6.4 secs : infill_ei
#
# [mbo] 121: cp=-0.92; minsplit=1728; minbucket=713; maxdepth=8 : y = 1.85e+07 : 13.1 secs : infill_ei
#
# [mbo] 122: cp=-0.739; minsplit=56; minbucket=27; maxdepth=7 : y = 2.03e+07 : 11.9 secs : infill_ei
#
# [mbo] 123: cp=-0.75; minsplit=779; minbucket=387; maxdepth=4 : y = 1.8e+07 : 8.0 secs : infill_ei
#
# [mbo] 124: cp=-0.47; minsplit=989; minbucket=360; maxdepth=5 : y = 1.82e+07 : 9.3 secs : infill_ei
#
# Saved the current state after iteration 125 in the file ./E1000_rpart.RDATA.
#
# [mbo] 125: cp=-0.112; minsplit=2621; minbucket=307; maxdepth=20 : y = 1.83e+07 : 19.5 secs : infill_ei
#
# [mbo] 126: cp=-0.475; minsplit=2848; minbucket=1412; maxdepth=20 : y = 1.84e+07 : 15.3 secs : infill_ei
#
# [mbo] 127: cp=-0.239; minsplit=4009; minbucket=1999; maxdepth=5 : y = 1.75e+07 : 9.0 secs : infill_ei
#
# [mbo] 128: cp=-0.33; minsplit=2934; minbucket=1467; maxdepth=16 : y = 1.8e+07 : 14.9 secs : infill_ei
#
# Saved the current state after iteration 129 in the file ./E1000_rpart.RDATA.
#
# [mbo] 129: cp=-0.913; minsplit=7993; minbucket=7; maxdepth=3 : y = 1.59e+07 : 6.3 secs : infill_ei
#
# [mbo] 130: cp=-0.472; minsplit=4446; minbucket=188; maxdepth=20 : y = 1.56e+07 : 21.7 secs : infill_ei
#
# [mbo] 131: cp=-0.583; minsplit=2543; minbucket=1269; maxdepth=20 : y = 1.86e+07 : 15.3 secs : infill_ei
#
# [mbo] 132: cp=-0.911; minsplit=4051; minbucket=2000; maxdepth=20 : y = 1.75e+07 : 13.5 secs : infill_ei
#
# Saved the current state after iteration 133 in the file ./E1000_rpart.RDATA.
#
# [mbo] 133: cp=-0.743; minsplit=1284; minbucket=2; maxdepth=8 : y = 2.02e+07 : 12.7 secs : infill_ei
#
# [mbo] 134: cp=-0.47; minsplit=633; minbucket=144; maxdepth=8 : y = 2.05e+07 : 13.1 secs : infill_ei
#
# [mbo] 135: cp=0.0129; minsplit=3039; minbucket=973; maxdepth=13 : y = 0 : 10.1 secs : infill_ei
#
# [mbo] 136: cp=-0.429; minsplit=2802; minbucket=1199; maxdepth=7 : y = 1.86e+07 : 11.3 secs : infill_ei
#
# [mbo] 137: cp=-0.625; minsplit=8000; minbucket=1; maxdepth=20 : y = 1.52e+07 : 22.7 secs : infill_ei
#
# Saved the current state after iteration 138 in the file ./E1000_rpart.RDATA.
#
# [mbo] 138: cp=-0.109; minsplit=6445; minbucket=1997; maxdepth=3 : y = 1.53e+07 : 6.6 secs : infill_ei
#
# [mbo] 139: cp=-0.107; minsplit=7994; minbucket=38; maxdepth=20 : y = 1.52e+07 : 20.8 secs : infill_ei
#
# [mbo] 140: cp=-0.729; minsplit=116; minbucket=8; maxdepth=10 : y = 1.94e+07 : 16.3 secs : infill_ei
#
# [mbo] 141: cp=-0.611; minsplit=2050; minbucket=1021; maxdepth=14 : y = 1.9e+07 : 16.1 secs : infill_ei
#
# Saved the current state after iteration 142 in the file ./E1000_rpart.RDATA.
#
# [mbo] 142: cp=-0.173; minsplit=2938; minbucket=1466; maxdepth=20 : y = 1.8e+07 : 14.9 secs : infill_ei
#
# [mbo] 143: cp=-0.0852; minsplit=1426; minbucket=266; maxdepth=20 : y = 1.96e+07 : 20.3 secs : infill_ei
#
# [mbo] 144: cp=-0.815; minsplit=3038; minbucket=1519; maxdepth=20 : y = 1.76e+07 : 15.4 secs : infill_ei
#
# [mbo] 145: cp=-0.146; minsplit=1837; minbucket=363; maxdepth=17 : y = 1.86e+07 : 19.1 secs : infill_ei
#
# Saved the current state after iteration 146 in the file ./E1000_rpart.RDATA.
#
# [mbo] 146: cp=-0.338; minsplit=580; minbucket=142; maxdepth=7 : y = 2.1e+07 : 11.9 secs : infill_ei
#
# [mbo] 147: cp=-0.232; minsplit=2705; minbucket=25; maxdepth=11 : y = 1.66e+07 : 15.9 secs : infill_ei
#
# [mbo] 148: cp=-1; minsplit=2275; minbucket=496; maxdepth=20 : y = 1.82e+07 : 17.5 secs : infill_ei
#
# [mbo] 149: cp=-1; minsplit=5800; minbucket=2000; maxdepth=20 : y = 1.59e+07 : 13.1 secs : infill_ei
#
# Saved the current state after iteration 150 in the file ./E1000_rpart.RDATA.
#
# [mbo] 150: cp=-0.523; minsplit=1865; minbucket=929; maxdepth=18 : y = 1.8e+07 : 16.2 secs : infill_ei
#
# [mbo] 151: cp=-0.179; minsplit=3288; minbucket=1638; maxdepth=9 : y = 1.75e+07 : 13.2 secs : infill_ei
#
# [mbo] 152: cp=-0.334; minsplit=7999; minbucket=120; maxdepth=4 : y = 1.52e+07 : 7.8 secs : infill_ei
#
# [mbo] 153: cp=-0.397; minsplit=4729; minbucket=1308; maxdepth=20 : y = 1.63e+07 : 14.6 secs : infill_ei
#
# Saved the current state after iteration 154 in the file ./E1000_rpart.RDATA.
#
# [mbo] 154: cp=-0.859; minsplit=7999; minbucket=9; maxdepth=20 : y = 1.52e+07 : 22.1 secs : infill_ei
#
# [mbo] 155: cp=-0.899; minsplit=3998; minbucket=1992; maxdepth=3 : y = 1.64e+07 : 6.8 secs : infill_ei
#
# [mbo] 156: cp=-0.337; minsplit=7996; minbucket=28; maxdepth=20 : y = 1.51e+07 : 20.9 secs : infill_ei
#
# [mbo] 157: cp=-0.96; minsplit=548; minbucket=1; maxdepth=7 : y = 2e+07 : 11.8 secs : infill_ei
#
# Saved the current state after iteration 158 in the file ./E1000_rpart.RDATA.
#
# [mbo] 158: cp=-0.479; minsplit=8000; minbucket=877; maxdepth=20 : y = 1.53e+07 : 15.0 secs : infill_ei
#
# [mbo] 159: cp=0.0997; minsplit=7998; minbucket=1980; maxdepth=3 : y = 0 : 6.6 secs : infill_ei
#
# [mbo] 160: cp=-0.0785; minsplit=1381; minbucket=189; maxdepth=3 : y = 1.6e+07 : 6.8 secs : infill_ei
#
# [mbo] 161: cp=-0.701; minsplit=7999; minbucket=1427; maxdepth=3 : y = 1.53e+07 : 7.1 secs : infill_ei
#
# [mbo] 162: cp=-0.661; minsplit=4897; minbucket=1221; maxdepth=20 : y = 1.59e+07 : 14.7 secs : infill_ei
#
# Saved the current state after iteration 163 in the file ./E1000_rpart.RDATA.
#
# [mbo] 163: cp=-0.105; minsplit=1716; minbucket=858; maxdepth=20 : y = 1.85e+07 : 17.0 secs : infill_ei
#
# [mbo] 164: cp=-0.329; minsplit=3190; minbucket=1589; maxdepth=6 : y = 1.78e+07 : 10.4 secs : infill_ei
#
# [mbo] 165: cp=-0.909; minsplit=3671; minbucket=1032; maxdepth=18 : y = 1.74e+07 : 15.7 secs : infill_ei
#
# [mbo] 166: cp=-0.438; minsplit=3709; minbucket=1853; maxdepth=18 : y = 1.73e+07 : 13.8 secs : infill_ei
#
# Saved the current state after iteration 167 in the file ./E1000_rpart.RDATA.
#
# [mbo] 167: cp=-0.703; minsplit=7989; minbucket=12; maxdepth=13 : y = 1.52e+07 : 16.1 secs : infill_ei
#
# [mbo] 168: cp=-0.215; minsplit=8000; minbucket=871; maxdepth=6 : y = 1.53e+07 : 9.9 secs : infill_ei
#
# [mbo] 169: cp=-0.589; minsplit=1920; minbucket=1; maxdepth=17 : y = 1.85e+07 : 23.3 secs : infill_ei
#
# [mbo] 170: cp=-0.968; minsplit=4012; minbucket=2000; maxdepth=10 : y = 1.75e+07 : 13.6 secs : infill_ei
#
# Saved the current state after iteration 171 in the file ./E1000_rpart.RDATA.
#
# [mbo] 171: cp=-0.335; minsplit=1744; minbucket=2; maxdepth=7 : y = 1.95e+07 : 11.7 secs : infill_ei
#
# [mbo] 172: cp=-1; minsplit=7999; minbucket=106; maxdepth=8 : y = 1.55e+07 : 11.8 secs : infill_ei
#
# [mbo] 173: cp=-0.626; minsplit=5994; minbucket=2000; maxdepth=3 : y = 1.59e+07 : 6.7 secs : infill_ei
#
# [mbo] 174: cp=-0.12; minsplit=4407; minbucket=1225; maxdepth=6 : y = 1.57e+07 : 10.3 secs : infill_ei
#
# [mbo] 175: cp=-0.848; minsplit=3267; minbucket=1629; maxdepth=10 : y = 1.78e+07 : 14.1 secs : infill_ei
#
# Saved the current state after iteration 176 in the file ./E1000_rpart.RDATA.
#
# [mbo] 176: cp=-0.588; minsplit=636; minbucket=132; maxdepth=7 : y = 2.15e+07 : 12.2 secs : infill_ei
#
# [mbo] 177: cp=-1; minsplit=6101; minbucket=1473; maxdepth=3 : y = 1.59e+07 : 6.8 secs : infill_ei
#
# [mbo] 178: cp=-0.549; minsplit=2885; minbucket=1440; maxdepth=15 : y = 1.84e+07 : 15.2 secs : infill_ei
#
# [mbo] 179: cp=-0.918; minsplit=6267; minbucket=2; maxdepth=12 : y = 1.53e+07 : 16.2 secs : infill_ei
#
# Saved the current state after iteration 180 in the file ./E1000_rpart.RDATA.
#
# [mbo] 180: cp=-0.0732; minsplit=7006; minbucket=4; maxdepth=13 : y = 1.53e+07 : 16.9 secs : infill_ei
#
# [mbo] 181: cp=-0.586; minsplit=7999; minbucket=1440; maxdepth=9 : y = 1.53e+07 : 12.4 secs : infill_ei
#
# [mbo] 182: cp=-0.305; minsplit=3733; minbucket=1052; maxdepth=20 : y = 1.69e+07 : 15.8 secs : infill_ei
#
# [mbo] 183: cp=-0.578; minsplit=2156; minbucket=134; maxdepth=7 : y = 1.84e+07 : 12.0 secs : infill_ei
#
# Saved the current state after iteration 184 in the file ./E1000_rpart.RDATA.
#
# [mbo] 184: cp=-0.676; minsplit=2674; minbucket=3; maxdepth=14 : y = 1.79e+07 : 19.8 secs : infill_ei
#
# [mbo] 185: cp=-0.434; minsplit=3822; minbucket=145; maxdepth=6 : y = 1.6e+07 : 10.3 secs : infill_ei
#
# [mbo] 186: cp=-0.0542; minsplit=7997; minbucket=1999; maxdepth=20 : y = 1.53e+07 : 13.0 secs : infill_ei
#
# [mbo] 187: cp=-0.805; minsplit=5368; minbucket=1214; maxdepth=3 : y = 1.59e+07 : 6.9 secs : infill_ei
#
# Saved the current state after iteration 188 in the file ./E1000_rpart.RDATA.
#
# [mbo] 188: cp=-0.466; minsplit=7960; minbucket=947; maxdepth=6 : y = 1.53e+07 : 9.9 secs : infill_ei
#
# [mbo] 189: cp=-0.328; minsplit=5489; minbucket=1268; maxdepth=3 : y = 1.59e+07 : 6.8 secs : infill_ei
#
# [mbo] 190: cp=-0.809; minsplit=7998; minbucket=933; maxdepth=13 : y = 1.53e+07 : 14.3 secs : infill_ei
#
# [mbo] 191: cp=-0.55; minsplit=3694; minbucket=892; maxdepth=20 : y = 1.72e+07 : 16.4 secs : infill_ei
#
# [mbo] 192: cp=-1; minsplit=7992; minbucket=1992; maxdepth=11 : y = 1.53e+07 : 12.8 secs : infill_ei
#
# Saved the current state after iteration 193 in the file ./E1000_rpart.RDATA.
#
# [mbo] 193: cp=-0.251; minsplit=7145; minbucket=1; maxdepth=15 : y = 1.54e+07 : 18.8 secs : infill_ei
#
# [mbo] 194: cp=-0.478; minsplit=520; minbucket=135; maxdepth=7 : y = 2.13e+07 : 12.0 secs : infill_ei
#
# [mbo] 195: cp=-0.387; minsplit=7998; minbucket=1837; maxdepth=14 : y = 1.53e+07 : 13.0 secs : infill_ei
#
# [mbo] 196: cp=-0.596; minsplit=750; minbucket=129; maxdepth=7 : y = 2.11e+07 : 12.1 secs : infill_ei
#
# Saved the current state after iteration 197 in the file ./E1000_rpart.RDATA.
#
# [mbo] 197: cp=-0.258; minsplit=2698; minbucket=1347; maxdepth=13 : y = 1.84e+07 : 15.2 secs : infill_ei
#
# [mbo] 198: cp=-0.665; minsplit=1289; minbucket=3; maxdepth=7 : y = 1.96e+07 : 11.7 secs : infill_ei
#
# [mbo] 199: cp=-0.962; minsplit=1112; minbucket=268; maxdepth=10 : y = 2.03e+07 : 15.6 secs : infill_ei
#
# [mbo] 200: cp=-0.766; minsplit=2643; minbucket=1319; maxdepth=16 : y = 1.84e+07 : 15.6 secs : infill_ei
#
# Saved the final state in the file ./E1000_rpart.RDATA
#
# Saved the final state in the file ./E1000_rpart.RDATA

# %%
quit( save="no" )
